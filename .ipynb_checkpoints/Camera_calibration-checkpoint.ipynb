# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

import glob
import sys, argparse
from scipy import optimize as opt

# %%
basepath = os.getcwd()
datapath = basepath + '/data/Calibration_Imgs/'

PatternSize = (12,12)
SquareSize = 1.0
# for imagefile ,in os.listdir(datapath):
I = cv2.imread(datapath + 'IMG_20170209_042606.jpg')

plt.figure(1, figsize = [14,14])
plt.imshow(cv2.cvtColor(I, cv2.COLOR_RGB2BGR))

# %%
def show_image(image):
    plt.figure(1, figsize = [14,14])
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

# %%
retVal, corners = cv2.findChessboardCorners(I, (9,6), None)
print(retVal)

objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.

if retVal == True:
#     objpoints.append(objp)
#     corners2 = cv2.cornerSubPix(gray,corners,(11,11),(-1,-1),criteria)
#     imgpoints.append(corners2)
    # Draw and display the corners
    I = cv2.drawChessboardCorners(I, PatternSize, corners,retVal)
    plt.figure(1, figsize = [14,14])
    plt.imshow(cv2.cvtColor(I, cv2.COLOR_RGB2BGR))
# Out:
# True
